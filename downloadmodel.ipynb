# %%
from sentence_transformers import SentenceTransformer
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM
from huggingface_hub import login

# OPTIONAL: log in directly in Python if you have a token
# Replace "hf_xxx..." with your Hugging Face token

login(token="put token here")

# 1️⃣ Download sentence-transformers/all-MiniLM-L6-v2
st_model_name = "sentence-transformers/all-MiniLM-L6-v2"
st_model = SentenceTransformer(st_model_name)
print(f"Downloaded {st_model_name} to cache.")

# 2️⃣ Download google/flan-t5-small
flan_model_name = "google/flan-t5-small"
tokenizer = AutoTokenizer.from_pretrained(flan_model_name)
model = AutoModelForSeq2SeqLM.from_pretrained(flan_model_name)
print(f"Downloaded {flan_model_name} to cache.")
# Out:
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# Cancellation requested; stopping current tasks.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/Documents/Code/NLP_Uni/.venv/lib/python3.11/site-packages/huggingface_hub/file_download.py:626, in xet_get(incomplete_path, xet_file_data, headers, expected_size, displayed_filename, _tqdm_bar)
#     624     progress.update(progress_bytes)
# --> 626 download_files(
#     627     xet_download_info,
#     628     endpoint=connection_info.endpoint,
#     629     token_info=(connection_info.access_token, connection_info.expiration_unix_epoch),
#     630     token_refresher=token_refresher,
#     631     progress_updater=[progress_updater],
#     632 )
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# ...
