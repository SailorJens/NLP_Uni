# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM
from huggingface_hub import login

# OPTIONAL: log in directly in Python if you have a token
# Replace "hf_xxx..." with your Hugging Face token

login(token="insert_your_token_here")  # Replace with your actual token

# %%
# 1️⃣ Download sentence-transformers/all-MiniLM-L6-v2
from sentence_transformers import SentenceTransformer
st_model_name = "sentence-transformers/all-MiniLM-L6-v2"
st_model = SentenceTransformer(st_model_name)
print(f"Downloaded {st_model_name} to cache.")

# %%
# 2️⃣ Download google/flan-t5-base
flan_model_name = "google/flan-t5-base"
tokenizer = AutoTokenizer.from_pretrained(flan_model_name)
model = AutoModelForSeq2SeqLM.from_pretrained(flan_model_name)
print(f"Downloaded {flan_model_name} to cache.")
# Out:
# model.safetensors:   0%|          | 0.00/990M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]
# Downloaded google/flan-t5-base to cache.

# %%
from transformers import AutoTokenizer, AutoModelForMaskedLM

deberta_model_name = "microsoft/deberta-v3-base"

# Force use of the slow tokenizer (Python implementation)
tokenizer = AutoTokenizer.from_pretrained(deberta_model_name)

# Load the model
model = AutoModelForMaskedLM.from_pretrained(deberta_model_name)

print(f"Downloaded {deberta_model_name} to cache.")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/Documents/Code/NLP_Uni/nlp_env/lib/python3.14/site-packages/transformers/convert_slow_tokenizer.py:1725, in convert_slow_tokenizer(transformer_tokenizer, from_tiktoken)
#    1721     logger.info("Converting from Tiktoken")
#    1722     return TikTokenConverter(
#    1723         vocab_file=transformer_tokenizer.vocab_file,
#    1724         additional_special_tokens=transformer_tokenizer.additional_special_tokens,
# -> 1725     ).converted()
#    1726 except Exception:
#
# File ~/Documents/Code/NLP_Uni/nlp_env/lib/python3.14/site-packages/transformers/convert_slow_tokenizer.py:1622, in TikTokenConverter.converted(self)
#    1621 def converted(self) -> Tokenizer:
# -> 1622     tokenizer = self.tokenizer()
#    1623     tokenizer.pre_tokenizer = pre_tokenizers.Sequence(
#    1624         [
# ...

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM

model_name = "meta-llama/Llama-3.2-1B-Instruct"

tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(model_name)

print(f"Downloaded {model_name} to cache.")
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File ~/Documents/Code/NLP_Uni/nlp_env/lib/python3.14/site-packages/huggingface_hub/utils/_http.py:402, in hf_raise_for_status(response, endpoint_name)
#     401 try:
# --> 402     response.raise_for_status()
#     403 except HTTPError as e:
#
# File ~/Documents/Code/NLP_Uni/nlp_env/lib/python3.14/site-packages/requests/models.py:1026, in Response.raise_for_status(self)
#    1025 if http_error_msg:
# -> 1026     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 403 Client Error: Forbidden for url: https://huggingface.co/meta-llama/Llama-3.2-1B-Instruct/resolve/main/config.json
#
# The above exception was the direct cause of the following exception:
#
# GatedRepoError                            Traceback (most recent call last)
# ...

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM

model_name = "microsoft/Phi-3-mini-4k-instruct"

tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(model_name)

print(f"Downloaded {model_name} to cache.")
# Out:
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# added_tokens.json:   0%|          | 0.00/306 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/599 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/967 [00:00<?, ?B/s]
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# ...
# model-00001-of-00002.safetensors:   0%|          | 0.00/4.97G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/2.67G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/181 [00:00<?, ?B/s]
# Downloaded microsoft/Phi-3-mini-4k-instruct to cache.
