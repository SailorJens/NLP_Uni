# %%
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer, PorterStemmer
from nltk.tokenize import word_tokenize

document = """Сегодня утром в Москве прошла пресс-конференция Министерства энергетики, на которой обсудили перспективы развития возобновляемых источников энергии в России. По словам представителей ведомства, в ближайшие пять лет планируется увеличение доли солнечных и ветровых станций в общей структуре энергогенерации страны. Особое внимание уделяется регионам с высоким потенциалом инсоляции — Калмыкии, Астраханской и Волгоградской областям. Также отмечалось, что инвесторы проявляют растущий интерес к проектам по производству и хранению водорода. Правительство готовит пакет налоговых льгот и субсидий, чтобы стимулировать компании к внедрению экологичных технологий. По оценкам экспертов, реализация программы позволит сократить выбросы углекислого газа на 12 % уже к 2030 году и создаст более десяти тысяч новых рабочих мест в энергетическом секторе.
Кроме того, на конференции были представлены новые разработки в области энергоэффективности и цифровизации энергетической инфраструктуры. В частности, обсуждались возможности использования искусственного интеллекта для оптимизации распределения электроэнергии и повышения надежности сетей. Участники мероприятия подчеркнули важность международного сотрудничества в сфере устойчивого развития энергетики и обмена передовыми технологиями. В завершение пресс-конференции министр энергетики отметил, что переход к зеленой энергетике является приоритетом государственной политики и ключевым фактором обеспечения энергетической безопасности страны в долгосрочной перспективе."""

docs = [document]
from typing import List

def my_preprocess(text: str, remove_stop: bool = True, lemmatize: bool = True) -> str:
    tokens = word_tokenize(text)
    tokens = [t.lower() for t in tokens if t.isalpha()]
    if remove_stop:
        stop_words = set(stopwords.words("russian"))
        tokens = [t for t in tokens if t not in stop_words]
    if lemmatize:
         lemmatizer = WordNetLemmatizer()
         tokens = [lemmatizer.lemmatize(t) for t in tokens]
    else:
         stemmer = PorterStemmer()
         tokens = [stemmer.stem(t) for t in tokens]
    return " ".join(tokens)

docs_clean = [my_preprocess(d) for d in docs]
docs_clean
# Out:
# ['сегодня утром москве прошла министерства энергетики которой обсудили перспективы развития возобновляемых источников энергии россии словам представителей ведомства ближайшие пять лет планируется увеличение доли солнечных ветровых станций общей структуре энергогенерации страны особое внимание уделяется регионам высоким потенциалом инсоляции калмыкии астраханской волгоградской областям также отмечалось инвесторы проявляют растущий интерес проектам производству хранению водорода правительство готовит пакет налоговых льгот субсидий стимулировать компании внедрению экологичных технологий оценкам экспертов реализация программы позволит сократить выбросы углекислого газа году создаст десяти тысяч новых рабочих мест энергетическом секторе кроме конференции представлены новые разработки области энергоэффективности цифровизации энергетической инфраструктуры частности обсуждались возможности использования искусственного интеллекта оптимизации распределения электроэнергии повышения надежности сетей участники мероприятия подчеркнули важность международного сотрудничества сфере устойчивого развития энергетики обмена передовыми технологиями завершение министр энергетики отметил переход зеленой энергетике является приоритетом государственной политики ключевым фактором обеспечения энергетической безопасности страны долгосрочной перспективе']

# %%
with open("WarAndPeace_original.txt", "r", encoding="utf-8") as f:
    text = f.read()

print(text[:500])
# Out:
# Ñïàñèáî, ÷òî ñêà÷àëè êíèãó â áåñïëàòíîé ýëåêòðîííîé áèáëèîòåêå Royallib.ru: http://royallib.ru
#
# Âñå êíèãè àâòîðà: http://royallib.ru/author/tolstoy_lev.html
#
# Ýòà æå êíèãà â äðóãèõ ôîðìàòàõ: http://royallib.ru/book/tolstoy_lev/voyna_i_mir_kniga_1.html
#
# Ïðèÿòíîãî ÷òåíèÿ!
#
#
#
#
#
# Òîì ïåðâûé
#
#
#
# ×àñòü ïåðâàÿ
#
#
#
# I
#
# – Eh bien, mon prince. G&#234;nes et Lucques ne sont plus que des apanages, des ïîìåñòüÿ, de la famille Buonaparte. Non, je vous pr&#233;viens que si vous ne me dites pas que nous avons la gue

# %%
import chardet

with open("WarAndPeace_original.txt", "rb") as f:
    raw = f.read()

result = chardet.detect(raw)
print(result)
# Out:
# {'encoding': 'utf-8', 'confidence': 0.99, 'language': ''}

# %%
# Step 1: Read the double-encoded UTF-8 file
with open("WarAndPeace_original.txt", "r", encoding="utf-8") as f:
    text_double_encoded = f.read()

# Step 2: Encode it as bytes using 'latin1' to recover the original bytes
bytes_original = text_double_encoded.encode('latin1', errors='ignore')

# Step 3: Decode using the correct Windows-1251
text_correct = bytes_original.decode('windows-1251')

# Optional: Handle HTML entities if present
import html
text_correct = html.unescape(text_correct)

# Step 4: Save as UTF-8
with open("file_utf8.txt", "w", encoding="utf-8") as f:
    f.write(text_correct)

# %%
import ftfy

with open("WarAndPeace_original.txt", "r", encoding="utf-8") as f:
    text = f.read()

text_fixed = ftfy.fix_text(text)

with open("WarAndPeace_utf8.txt", "w", encoding="utf-8") as f:
    f.write(text_fixed)

# %%
import re
from sklearn.feature_extraction.text import CountVectorizer
import inspect

if not hasattr(inspect, 'getargspec'):
    inspect.getargspec = inspect.getfullargspec

import pymorphy2
import nltk

# Download Russian stopwords if not already
nltk.download('stopwords')
from nltk.corpus import stopwords

# 1. Read UTF-8 Russian text file
with open("WarAndPeace_utf8.txt", "r", encoding="utf-8") as f:
    text = f.read()

# 2. Preprocessing: lowercase + remove non-alphabetic characters
text = text.lower()
text = re.sub(r'[^а-яё\s]', ' ', text)  # keep only Cyrillic letters and spaces

# 3. Tokenization
tokens = text.split()

# 4. Lemmatization
morph = pymorphy2.MorphAnalyzer()
lemmatized_tokens = [morph.parse(token)[0].normal_form for token in tokens]

# 5. Remove stopwords
russian_stopwords = set(stopwords.words('russian'))
tokens_clean = [token for token in lemmatized_tokens if token not in russian_stopwords]

# 6. Reconstruct cleaned text for BoW
clean_text = " ".join(tokens_clean)

# 7. Bag-of-Words using scikit-learn
vectorizer = CountVectorizer()
X = vectorizer.fit_transform([clean_text])  # you can pass a list of documents

# 8. Output
# print("Feature names (words):", vectorizer.get_feature_names_out())
# print("Bag-of-Words vector:", X.toarray())

# Print the most frequent 200 words with frequencysies
import numpy as np
bow_vec = CountVectorizer(max_features=10000, ngram_range=(1,1))
X_bow = bow_vec.fit_transform([clean_text])
terms_bow = np.array(bow_vec.get_feature_names_out())
# Out:
# [nltk_data] Downloading package stopwords to /Users/jus/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
bow_sum = np.array(X_bow.sum(axis=0)).flatten()
# Get indices of the top 10 terms (in the correct order) 
# ie. sort the sum array, take the last 10 indices, and reverse them to get descending order
# Most frequent
# bow_indices = np.argsort(bow_sum)[-1000:][::-1]
# Least frequent
bow_indices = np.argsort(bow_sum)[:1000]
top_terms = []
top_counts = []
print("Top 10 Bag of Words terms:")
for idx in bow_indices:
    top_terms.append(bow_vec.get_feature_names_out()[idx])
    top_counts.append(bow_sum[idx])
    print(f"  {bow_vec.get_feature_names_out()[idx]}: {bow_sum[idx]}")
# Out:
# Top 10 Bag of Words terms:
#   аа: 1
#   золотистый: 1
#   зоркий: 1
#   зравие: 1
#   стенной: 1
#   зрячий: 1
#   стекаться: 1
#   стекать: 1
#   стезя: 1
#   иверсковать: 1
#   игнатиевич: 1
#   игнашка: 1
#   стегнуть: 1
#   стегно: 1
#   стебель: 1
#   игреневый: 1
#   игривый: 1
#   ствол: 1
#   игрушечный: 1
#   ство: 1
#   идиот: 1
#   идиотизм: 1
#   степенность: 1
#   знаэта: 1
#   значиться: 1
#   стереть: 1
#   стотысячный: 1
#   сторонник: 1
#   земский: 1
#   стоптать: 1
#   зикина: 1
#   злеть: 1
#   столичный: 1
#   столетний: 1
#   столбик: 1
#   зловещий: 1
#   иена: 1
#   стойко: 1
#   змея: 1
#   знайта: 1
#   стихотворение: 1
#   стихийный: 1
#   стиснуть: 1
#   стирать: 1
#   стеснительно: 1
#   значимый: 1
#   стерпеться: 1
#   значительность: 1
#   злопамятный: 1
#   зелье: 1
#   иерархия: 1
#   статуеобразный: 1
#   изготовляться: 1
#   изгубить: 1
#   издали: 1
#   станционный: 1
#   издать: 1
#   издохнуть: 1
#   издыхать: 1
#   изливать: 1
#   излишек: 1
#   измаил: 1
#   становящий: 1
#   станина: 1
#   стальной: 1
#   изменяемый: 1
#   сталкиваться: 1
#   изменяться: 1
#   измокнуть: 1
#   измытый: 1
#   изнеможение: 1
#   изножие: 1
#   изнурить: 1
#   изгонять: 1
#   изголовье: 1
#   изгнать: 1
#   старание: 1
#   избавление: 1
#   избавлять: 1
#   избаловать: 1
#   статный: 1
#   избежание: 1
#   избить: 1
#   избрание: 1
#   изведать: 1
#   известиться: 1
#   старомодный: 1
#   иерусалим: 1
#   старогусарский: 1
#   стареющийся: 1
#   старец: 1
#   стареться: 1
#   извинять: 1
#   старенький: 1
#   извлекать: 1
#   извлечь: 1
#   извозчичий: 1
#   изворотливость: 1
#   изгибаться: 1
#   извиваться: 1
#   стояться: 1
#   стоячий: 1
#   зевота: 1
#   засыхать: 1
#   затащить: 1
#   стягивать: 1
#   затвориться: 1
#   стыдный: 1
#   затемнить: 1
#   затереть: 1
#   затереться: 1
#   затесаться: 1
#   затея: 1
#   затихание: 1
#   ступня: 1
#   затмение: 1
#   затравить: 1
#   затрепать: 1
#   затрепаться: 1
#   стульчик: 1
#   затрогивать: 1
#   стукнуться: 1
#   затруднительно: 1
#   затруднительный: 1
#   стянуть: 1
#   засыпание: 1
#   стёганый: 1
#   засучиваться: 1
#   заслать: 1
#   заслонка: 1
#   заслонять: 1
#   заслушаться: 1
#   сударь: 1
#   засопеть: 1
#   засохнуть: 1
#   заспешить: 1
#   заспорить: 1
#   застава: 1
#   затрясти: 1
#   заставиться: 1
#   застигнуть: 1
#   застраховать: 1
#   заступ: 1
#   заступать: 1
#   заступнически: 1
#   стёшка: 1
#   стёрн: 1
#   засумятилися: 1
#   засунуть: 1
#   засучивать: 1
#   суббота: 1
#   затрястись: 1
#   затуманить: 1
#   затэ: 1
#   защита: 1
#   защищаться: 1
#   защёлкать: 1
#   заявить: 1
#   заячий: 1
#   заём: 1
#   стрелковый: 1
#   стрела: 1
#   стрекоза: 1
#   звено: 1
#   защекотать: 1
#   зверие: 1
#   звольт: 1
#   страусовый: 1
#   звонок: 1
#   страстность: 1
#   стражение: 1
#   страждущий: 1
#   страдальческий: 1
#   здравие: 1
#   здравый: 1
#   зевать: 1
#   страшить: 1
#   изнутри: 1
#   зашикать: 1
#   зашептаться: 1
#   затэм: 1
#   затягиваться: 1
#   затянутый: 1
#   затянуть: 1
#   зафыркать: 1
#   захарчёнок: 1
#   захарыч: 1
#   струя: 1
#   захлипать: 1
#   захлопать: 1
#   зашибиться: 1
#   стружка: 1
#   строка: 1
#   захрипеть: 1
#   строитель: 1
#   зачернеться: 1
#   зачислить: 1
#   зачумлённый: 1
#   зачэм: 1
#   зашататься: 1
#   стриженый: 1
#   зашептать: 1
#   захлопывать: 1
#   изобличать: 1
#   ссылка: 1
#   ссудить: 1
#   калёный: 1
#   камение: 1
#   каменистый: 1
#   каменно: 1
#   каменщица: 1
#   каменщицкий: 1
#   каменщичество: 1
#   соснуть: 1
#   камлотовый: 1
#   сослужить: 1
#   камчатный: 1
#   сослуживец: 1
#   канал: 1
#   канат: 1
#   сословный: 1
#   канцелярский: 1
#   капельдинер: 1
#   капельмейстер: 1
#   капитал: 1
#   сослан: 1
#   соскакивать: 1
#   калоша: 1
#   калека: 1
#   кале: 1
#   калач: 1
#   сохранение: 1
#   софья: 1
#   софи: 1
#   июньский: 1
#   йорк: 1
#   сотовый: 1
#   кабак: 1
#   кабриолет: 1
#   сосуд: 1
#   кавалергардов: 1
#   сосиска: 1
#   сострунить: 1
#   состареться: 1
#   кавалькада: 1
#   кавказ: 1
#   кадило: 1
#   составляться: 1
#   кажущийся: 1
#   казанский: 1
#   казарма: 1
#   казнокрад: 1
#   сосредоточенно: 1
#   состариться: 1
#   каприз: 1
#   каптенармус: 1
#   капуста: 1
#   кашлянуть: 1
#   кашлять: 1
#   каяться: 1
#   сообразно: 1
#   соображаться: 1
#   квартет: 1
#   квартирка: 1
#   квартирьер: 1
#   кгасавица: 1
#   кгома: 1
#   кашевар: 1
#   кгыс: 1
#   сонин: 1
#   сондирование: 1
#   сомнительный: 1
#   сомнительно: 1
#   сомкнуться: 1
#   кирил: 1
#   солфеджи: 1
#   соломонов: 1
#   кирюш: 1
#   соломон: 1
#   кемпийский: 1
#   ице: 1
#   сообразный: 1
#   католичка: 1
#   кара: 1
#   карабинер: 1
#   соседство: 1
#   сорокатысячный: 1
#   караулить: 1
#   карахтереть: 1
#   караюшка: 1
#   карла: 1
#   карлыкать: 1
#   карниз: 1
#   сообщаться: 1
#   каролина: 1
#   картавить: 1
#   сопрячь: 1
#   картинка: 1
#   соприкосновение: 1
#   сопеть: 1
#   соперничество: 1
#   карьер: 1
#   катание: 1
#   кататься: 1
#   сооонить: 1
#   сопутствуть: 1
#   заскрипеть: 1
#   итальянск: 1
#   сочинение: 1
#   сравнять: 1
#   империя: 1
#   импровизированный: 1
#   импэратор: 1
#   имущество: 1
#   сравнительный: 1
#   инна: 1
#   сравниваться: 1
#   иностранец: 1
#   сравнивать: 1
#   инстинктивно: 1
#   интеллигенция: 1
#   спугнуть: 1
#   спрос: 1
#   спроваживать: 1
#   справка: 1
#   интриговать: 1
#   иня: 1
#   спохватиться: 1
#   ипатка: 1
#   ипохондрия: 1
#   сравняться: 1
#   сражаться: 1
#   сразиться: 1
#   именной: 1
#   изобразиться: 1
#   изобразовать: 1
#   ссадина: 1
#   изречение: 1
#   изрядно: 1
#   изумлять: 1
#   изучать: 1
#   изучить: 1
#   изъявить: 1
#   изъяснение: 1
#   спотыкнуться: 1
#   изъяснить: 1
#   изящность: 1
#   иисус: 1
#   срываться: 1
#   срубить: 1
#   иллюминация: 1
#   иль: 1
#   ильинишный: 1
#   ильюшка: 1
#   срисовывать: 1
#   илюшка: 1
#   изюм: 1
#   ирина: 1
#   исказиться: 1
#   искатель: 1
#   спасительница: 1
#   спасаться: 1
#   спас: 1
#   испытующий: 1
#   иссечь: 1
#   иссыхать: 1
#   истаскать: 1
#   истаять: 1
#   истекать: 1
#   истекший: 1
#   испужаться: 1
#   сочувствовать: 1
#   сочность: 1
#   сочинять: 1
#   истощить: 1
#   истратиться: 1
#   истребляйть: 1
#   истребование: 1
#   исходить: 1
#   исхудать: 1
#   сочинитель: 1
#   итак: 1
#   истомленный: 1
#   итальянка: 1
#   спасский: 1
#   сперва: 1
#   искательство: 1
#   спотыкаться: 1
#   исключать: 1
#   спорщик: 1
#   исключить: 1
#   исковеркать: 1
#   искоренить: 1
#   искоса: 1
#   спорный: 1
#   сплетничать: 1
#   спастись: 1
#   списывать: 1
#   спиртовой: 1
#   исполинский: 1
#   спирт: 1
#   исполнимый: 1
#   исполнительный: 1
#   спираться: 1
#   исполняйт: 1
#   исполняться: 1
#   спех: 1
#   исправляться: 1
#   исповедовать: 1
#   кисея: 1
#   заскочить: 1
#   засиживаться: 1
#   толстенький: 1
#   жареный: 1
#   жарка: 1
#   толковаться: 1
#   жаровой: 1
#   жать: 1
#   жгать: 1
#   жгут: 1
#   толкануть: 1
#   желаемый: 1
#   токарный: 1
#   товарищеский: 1
#   ткнуться: 1
#   ткань: 1
#   тка: 1
#   тиша: 1
#   тихость: 1
#   тихонько: 1
#   женишок: 1
#   женственный: 1
#   тить: 1
#   толстеть: 1
#   жалостный: 1
#   толщина: 1
#   жалобный: 1
#   ездовой: 1
#   езжать: 1
#   езженный: 1
#   торговка: 1
#   елейный: 1
#   торговать: 1
#   еловый: 1
#   ер: 1
#   топчеёнка: 1
#   ерзынька: 1
#   титла: 1
#   топтание: 1
#   ефрейтор: 1
#   топнуть: 1
#   топко: 1
#   жаба: 1
#   жаворонок: 1
#   жадность: 1
#   томиться: 1
#   жажда: 1
#   томить: 1
#   жало: 1
#   топор: 1
#   торжествующе: 1
#   тиски: 1
#   тильзитский: 1
#   забавлять: 1
#   забавник: 1
#   телёнок: 1
#   забежать: 1
#   забивать: 1
#   забирать: 1
#   заблистать: 1
#   заблуждать: 1
#   тельце: 1
#   текст: 1
#   театральный: 1
#   заботливо: 1
#   тгубка: 1
#   заботливый: 1
#   забрасывать: 1
#   тганспогт: 1
#   забываться: 1
#   творец: 1
#   творение: 1
#   заваливаться: 1
#   завалиться: 1
#   темляк: 1
#   темь: 1
#   жучок: 1
#   жутко: 1
#   тесёмочка: 1
#   жестяной: 1
#   жжёный: 1
#   живать: 1
#   живописец: 1
#   живописно: 1
#   живописный: 1
#   терпение: 1
#   жизненный: 1
#   жизнерадостный: 1
#   тимофеич: 1
#   тереться: 1
#   жилой: 1
#   житейский: 1
#   теплота: 1
#   житие: 1
#   тенёта: 1
#   жмуриться: 1
#   жниво: 1
#   тенор: 1
#   тенисто: 1
#   жребий: 1
#   жилище: 1
#   ежеминутный: 1
#   торжок: 1
#   единый: 1
#   дотянуться: 1
#   трудящийся: 1
#   дочитать: 1
#   дочка: 1
#   дощатый: 1
#   др: 1
#   троякий: 1
#   драгунский: 1
#   драпировка: 1
#   дребезжать: 1
#   тротуарный: 1
#   дреймадера: 1
#   дробь: 1
#   дроворуб: 1
#   троица: 1
#   дрожечка: 1
#   троечный: 1
#   дрон: 1
#   тридцатипятитысячный: 1
#   дружелюбный: 1
#   тридцативерстный: 1
#   труп: 1
#   дотла: 1
#   дотанцевать: 1
#   досуг: 1
#   тюраса: 1
#   тыкать: 1
#   тщательность: 1
#   тушить: 1
#   тучность: 1
#   тучка: 1
#   тускло: 1
#   турчанка: 1
#   дореволюционный: 1
#   дорисовать: 1
#   дружка: 1
#   дормиро: 1
#   тупоумие: 1
#   досадливо: 1
#   туловище: 1
#   туд: 1
#   тряхнуться: 1
#   достигать: 1
#   тряпка: 1
#   достоверность: 1
#   трусость: 1
#   достопримечательность: 1
#   дорого: 1
#   дружно: 1
#   треугольник: 1
#   дря: 1
#   традиридир: 1
#   трагический: 1
#   травничка: 1
#   дышловый: 1
#   дьякон: 1
#   дьячок: 1
#   дюссекова: 1
#   точный: 1
#   дёмкин: 1
#   дёрн: 1
#   дымковыя: 1
#   точение: 1
#   тоскливый: 1
#   евангельский: 1
#   евгениевич: 1
#   торть: 1
#   торочить: 1
#   египтянин: 1
#   едать: 1
#   единодушно: 1
#   единорог: 1
#   торный: 1
#   дёрнуться: 1
#   заварзинский: 1
#   трактирщик: 1
#   дуэт: 1
#   дрянный: 1
#   дубина: 1
#   дубинка: 1
#   дубовый: 1
#   дубрава: 1
#   дугацкай: 1
#   трепет: 1
#   трепачка: 1
#   трепак: 1
#   трензель: 1
#   трата: 1
#   дурнота: 1
#   требоваться: 1
#   душевно: 1
#   требовательный: 1
#   траур: 1
#   душеприказчик: 1
#   душечка: 1
#   душистый: 1
#   душить: 1
#   душка: 1
#   трауна: 1
#   тревожиться: 1
#   завесить: 1
#   заветный: 1
#   завещать: 1
#   сучок: 1
#   сучковый: 1
#   замигать: 1
#   сухтельный: 1
#   сухтелена: 1
#   замириться: 1
#   замкнутый: 1
#   сухощавый: 1
#   замолаживать: 1
#   суфлёр: 1
#   сутулый: 1
#   заморозка: 1
#   сустав: 1
#   суровый: 1
#   суровость: 1
#   занести: 1
#   занималось: 1
#   сургуч: 1
#   занят: 1
#   запасной: 1
#   запасный: 1
#   сушиться: 1
#   заметка: 1
#   существующий: 1
#   заместо: 1
#   закупать: 1
#   закупорить: 1
#   закуривать: 1
#   закурить: 1
#   сход: 1
#   закусочка: 1
#   закутаться: 1
#   сформироваться: 1
#   залаять: 1
#   залив: 1
#   запастись: 1
#   заливаться: 1
#   сфинксовый: 1
#   заложиться: 1
#   залп: 1
#   заманивание: 1
#   заманивать: 1
#   заманить: 1
#   заманчивый: 1
#   заматывать: 1
#   замедление: 1
#   сущий: 1
#   залиться: 1
#   суматоха: 1
#   запахнуть: 1
#   запачкать: 1
#   запрягать: 1
#   запустить: 1
#   судорожный: 1
#   запущенность: 1
#   запылить: 1
#   судорожно: 1
#   запятнать: 1
#   зарево: 1
#   зарождаться: 1
#   заронить: 1
#   запрыгать: 1
#   зарумяниться: 1
#   судный: 1
#   зарыть: 1
#   зарыться: 1
#   судно: 1
#   судитэ: 1
#   зарядный: 1
#   засаживать: 1
#   судилище: 1
#   засекать: 1
#   засечь: 1
#   зарываться: 1
#   счастливец: 1
#   запрудить: 1
#   запрег: 1
#   запачкаться: 1
#   запевать: 1
#   запеканочка: 1
#   сумасбродный: 1
#   запереться: 1
#   сумасброд: 1
#   запечься: 1
#   запивать: 1
#   запинаться: 1
#   суконный: 1
#   суетиться: 1
#   сукин: 1
#   запить: 1
#   запихать: 1
#   сузиться: 1
#   сузить: 1
#   заплести: 1
#   заплетать: 1
#   запнуться: 1
#   запоминать: 1
#   запомниться: 1
#   запотеть: 1
#   записной: 1
#   заскакивать: 1
#   съедать: 1
#   закружить: 1
#   заглавие: 1
#   заглавный: 1
#   танцовывалить: 1
#   заглаживать: 1
#   заглушиться: 1
#   заглядываться: 1
#   загнутый: 1
#   танцовщик: 1
#   загнуться: 1
#   заговор: 1
#   заговорщик: 1
#   загорелый: 1
#   загореться: 1
#   загрубелый: 1
#   тактик: 1
#   задвигаться: 1
#   задвижка: 1
#   задвинуть: 1
#   тако: 1
#   задержаться: 1
#   задержка: 1
#   загибаться: 1
#   загадывать: 1
#   загадить: 1
#   завязываться: 1
#   завидный: 1
#   тащиться: 1
#   таш: 1
#   зависимость: 1
#   зависимый: 1
#   татарский: 1
#   татарка: 1
#   завитой: 1
#   завлечь: 1
#   завод: 1
#   таить: 1
#   заводила: 1
#   тат: 1
#   заворачиваться: 1
#   заворотить: 1
#   заворотиться: 1
#   завтг: 1
#   тараска: 1
#   завтракать: 1
#   тарас: 1
#   таперича: 1
#   завязнуть: 1
#   татарин: 1
#   задохнуться: 1
#   задребезжать: 1
#   задремать: 1
#   закашляться: 1
#   закготься: 1
#   закивать: 1
#   сыпаться: 1
#   заклинать: 1
#   заключать: 1
#   сынок: 1
#   заключение: 1
#   сынов: 1
#   заковывать: 1
#   закашлять: 1
#   заколебать: 1
#   заколоть: 1
#   съёжиться: 1
#   съехать: 1
#   законность: 1
#   законодательство: 1
#   закоптить: 1
#   закоренелый: 1
#   закраснеться: 1
#   закреплять: 1
#   закрой: 1
#   заколебаться: 1
#   закружиться: 1
#   закапать: 1
#   заискивающе: 1
#   задумчивость: 1
#   задуть: 1
#   задушевно: 1
#   задушить: 1
#   сякой: 1
#   зажаривать: 1
#   зажать: 1
#   заждаться: 1
#   зажжение: 1
#   заживать: 1
#   сырость: 1
#   зажиреть: 1
#   зажор: 1
#   зажужжать: 1
#   сытный: 1
#   зазимок: 1
#   зазывать: 1
#   сыскать: 1
#   заикаться: 1
#   заиндеветь: 1
#   заинтересованный: 1
#   заинтересовать: 1
#   зажить: 1
#   тюрьма: 1
#   соломенный: 1
#   китти: 1
#   сафи: 1
#   сатирик: 1
#   сатир: 1
#   сардонически: 1
#   сардинский: 1
#   сарафан: 1
#   сановитый: 1
#   самоуправство: 1
#   самоунижение: 1
#   самостоятельный: 1
#   самостоятельность: 1
#   самосохранение: 1
#   самосовершенствование: 1
#   самоосуждение: 1
#   самоосмеяние: 1
#   самообольщение: 1
#   самодовольно: 1
#   саломонить: 1
#   сажный: 1
#   савишной: 1
#   ряса: 1
#   сафьян: 1
#   сахара: 1
#   сбегаться: 1
#   сбиваться: 1
#   свистящий: 1
#   свисток: 1
#   свистнуть: 1
#   свистения: 1
#   свистать: 1
#   свидетельствовать: 1
#   светить: 1
#   свесить: 1
#   свершиться: 1
#   сверкнуть: 1
#   рязань: 1
#   свежесть: 1
#   сведущий: 1
#   свая: 1
#   сварить: 1
#   сваливать: 1
#   сбыться: 1
#   сбываться: 1
#   сбывать: 1
#   сбрить: 1
#   сбрасывать: 1
#   сборка: 1
#   свежевыбритый: 1
#   свихнуть: 1
#   рядиться: 1
#   рябеть: 1
#   рубануть: 1
#   рррра: 1
#   роялист: 1
#   роща: 1
#   ротик: 1
#   ростепель: 1
#   ростбиф: 1
#   рослый: 1
#   роскошно: 1
#   романический: 1
#   ром: 1
#   роковой: 1
#   розыск: 1
#   розовенький: 1
#   рознить: 1
#   розенкампф: 1
#   розан: 1
#   рожь: 1
#   рожок: 1
#   рожков: 1
#   рожество: 1
#   рубец: 1
#   руби: 1
#   рубило: 1
#   рубиться: 1
#   рюрик: 1
#   рэт: 1
#   рычаг: 1
#   рысь: 1
#   рысцой: 1
#   рыскать: 1
#   рыжеватый: 1
#   ручьём: 1
#   русь: 1
#   русачий: 1
#   рявкнуть: 1
#   руно: 1
#   румянец: 1
#   рукоплескание: 1
#   руководящий: 1
#   руководствоваться: 1
#   руководиться: 1
#   руководимый: 1
#   ругаться: 1
#   ругай: 1
#   рублёвый: 1
#   рубленый: 1
#   румяно: 1
#   свободомыслие: 1
#   свод: 1
#   свозить: 1
#   мартовский: 1
#   сетование: 1
#   сестгу: 1
#   маршрут: 1
#   серёжка: 1
#   марьинский: 1
#   сероватый: 1
#   сереться: 1
#   серединный: 1
#   мастерская: 1
#   мастерский: 1
#   масть: 1
#   матвевич: 1
#   математика: 1
#   математический: 1
#   материал: 1
#   материально: 1
#   материнский: 1
#   материщий: 1
#   сердечность: 1
#   матильда: 1
#   мартинист: 1
#   сеть: 1
#   марсовый: 1
#   марс: 1
#   майонез: 1
#   макать: 1
#   максимке: 1
#   макуш: 1
#   синева: 1
#   симпатия: 1
#   малодушие: 1
#   маложалостливый: 1
#   силач: 1
#   мальта: 1
#   матка: 1
#   сиживать: 1
#   мамонтовый: 1
#   мамушка: 1
#   сигара: 1
#   сивцева: 1
#   манифэстэ: 1
#   манна: 1
#   мантилья: 1
#   марат: 1
#   марго: 1
#   мародёрство: 1
#   сидорович: 1
#   матрёна: 1
#   матрёшка: 1
#   маутёрн: 1
#   седина: 1
#   сдунуть: 1
#   сдружиться: 1
#   сдерживаться: 1
#   сдержанность: 1
#   сдвинуться: 1
#   сдаточный: 1
#   сдавливать: 1
#   сгуститься: 1
#   сгруппироваться: 1
#   седморецкий: 1
#   сговор: 1
#   святотатственный: 1
#   святость: 1
#   святост: 1
#   связывание: 1
#   связующий: 1
#   связаться: 1
#   свояченица: 1
#   своэго: 1
#   своротить: 1
#   сворка: 1
#   святыня: 1
#   рожать: 1

# %%
bow_sum = np.array(X_bow.sum(axis=0)).flatten()

import numpy as np

# Create a mask for tokens with frequency >= 10
mask = bow_sum >= 10
valid_indices = np.where(mask)[0]  # indices of tokens with freq >= 10
valid_bow_sum = bow_sum[valid_indices]
sorted_indices = valid_indices[np.argsort(valid_bow_sum)[:1000]]

top_terms = []
top_counts = []
print("Top 10 Bag of Words terms:")
for idx in sorted_indices:
    top_terms.append(bow_vec.get_feature_names_out()[idx])
    top_counts.append(bow_sum[idx])
    print(f"  {bow_vec.get_feature_names_out()[idx]}: {bow_sum[idx]}")
# Out:
# Top 10 Bag of Words terms:
#   репутация: 10
#   величие: 10
#   прижать: 10
#   лететь: 10
#   ульм: 10
#   отчётливо: 10
#   привлекательный: 10
#   кутузовский: 10
#   охотно: 10
#   верховой: 10
#   удивлённый: 10
#   умоляющий: 10
#   приблизить: 10
#   удивиться: 10
#   очнуться: 10
#   удерживаться: 10
#   курагин: 10
#   кукла: 10
#   ошибаться: 10
#   крыло: 10
#   записать: 10
#   прибежать: 10
#   прерывать: 10
#   веселиться: 10
#   величественный: 10
#   велита: 10
#   сознавать: 10
#   опускать: 10
#   брюнна: 10
#   притворно: 10
#   оружие: 10
#   особа: 10
#   успокоивать: 10
#   магницкий: 10
#   усиливаться: 10
#   отказ: 10
#   усик: 10
#   любовник: 10
#   усесться: 10
#   василиевич: 10
#   политика: 10
#   василь: 10
#   вахмистр: 10
#   завести: 10
#   лунный: 10
#   везти: 10
#   отправляться: 10
#   ловить: 10
#   соединить: 10
#   лишить: 10
#   защищать: 10
#   предстоящий: 10
#   креститься: 10
#   убивать: 10
#   возбудить: 10
#   ключ: 10
#   возвращение: 10
#   поддерживать: 10
#   подмосковный: 10
#   квартальный: 10
#   избавиться: 10
#   спуститься: 10
#   камень: 10
#   вольный: 10
#   поражение: 10
#   пожимать: 10
#   кавалерист: 10
#   извиниться: 10
#   стыд: 10
#   источник: 10
#   помиловать: 10
#   польша: 10
#   польза: 10
#   искренно: 10
#   восхищаться: 10
#   всадник: 10
#   интрига: 10
#   тимохин: 10
#   устроиться: 10
#   водка: 10
#   погода: 10
#   вздыхать: 10
#   пасть: 10
#   тёплый: 10
#   союзник: 10
#   видимый: 10
#   почтительность: 10
#   костюм: 10
#   корпус: 10
#   трогать: 10
#   знание: 10
#   переслать: 10
#   перестрелка: 10
#   вкус: 10
#   комитет: 10
#   племянница: 10
#   потребность: 10
#   постараться: 10
#   победить: 10
#   повар: 10
#   золовка: 10
#   спорить: 10
#   религия: 10
#   книзу: 10
#   справа: 10
#   определить: 10
#   врать: 10
#   обдумывать: 10
#   довод: 10
#   мужество: 10
#   дождаться: 10
#   беспокойный: 10
#   сдерживать: 10
#   ценить: 10
#   бесчисленный: 10
#   ранец: 10
#   гул: 10
#   расставить: 10
#   обойтись: 10
#   должность: 10
#   биться: 10
#   разуметь: 10
#   раздражить: 10
#   дорожка: 10
#   объехать: 10
#   достаточно: 10
#   багровый: 10
#   снимать: 10
#   архитектор: 10
#   мучиться: 10
#   нерешительность: 10
#   шептать: 10
#   наделать: 10
#   неторопливо: 10
#   никуда: 10
#   чрез: 10
#   сведение: 10
#   свойство: 10
#   надевать: 10
#   нагибаться: 10
#   двинуться: 10
#   несомненно: 10
#   черёд: 10
#   бег: 10
#   свора: 10
#   связанный: 10
#   намереваться: 10
#   челюсть: 10
#   шерер: 10
#   человечество: 10
#   доверие: 10
#   ночью: 10
#   гроб: 10
#   разбитый: 10
#   расстаться: 10
#   скучать: 10
#   драгун: 10
#   скучный: 10
#   ругать: 10
#   слабо: 10
#   научить: 10
#   нахмурить: 10
#   шёпот: 10
#   девка: 10
#   промежуток: 10
#   эй: 10
#   энергия: 10
#   учение: 10
#   действительный: 10
#   независимо: 10
#   смешно: 10
#   резерв: 10
#   опасный: 10
#   произнести: 10
#   шубка: 10
#   нечаянно: 10
#   небрежно: 10
#   сие: 10
#   руководить: 10
#   растерять: 10
#   оголить: 10
#   дрова: 10
#   хитрый: 10
#   пытаться: 10
#   богданыч: 10
#   наряд: 10
#   многие: 10
#   одеться: 10
#   справедливый: 11
#   рассуждать: 11
#   избавить: 11
#   зрение: 11
#   получение: 11
#   способность: 11
#   посещение: 11
#   справедливо: 11
#   попасться: 11
#   расходиться: 11
#   справедливость: 11
#   поправить: 11
#   станция: 11
#   встреча: 11
#   детски: 11
#   вход: 11
#   поражать: 11
#   расспрашивать: 11
#   десятка: 11
#   ставить: 11
#   продолжение: 11
#   добродушный: 11
#   согласие: 11
#   пруссия: 11
#   советовать: 11
#   совесть: 11
#   прощаться: 11
#   заботиться: 11
#   прошлый: 11
#   след: 11
#   дымка: 11
#   пропускать: 11
#   пролететь: 11
#   прислуга: 11
#   смелый: 11
#   совершенный: 11
#   пристально: 11
#   производить: 11
#   живот: 11
#   присутствовать: 11
#   женить: 11
#   скрыться: 11
#   приняться: 11
#   пункт: 11
#   сойти: 11
#   постичь: 11
#   потеря: 11
#   выезжать: 11
#   расслышать: 11
#   выиграть: 11
#   спальня: 11
#   здравствуйте: 11
#   предположение: 11
#   преследовать: 11
#   вывести: 11
#   зарыдать: 11
#   сомневаться: 11
#   разжаловать: 11
#   занятой: 11
#   доходить: 11
#   соль: 11
#   замирать: 11
#   приглашение: 11
#   графинюшка: 11
#   дрогнуть: 11
#   соображать: 11
#   забытый: 11
#   однажды: 11
#   оглядеть: 11
#   лето: 11
#   холод: 11
#   укрепление: 11
#   ужинать: 11
#   беспокойно: 11
#   вертеться: 11
#   оценить: 11
#   блюдо: 11
#   фальшивый: 11
#   мягкий: 11
#   ошибка: 11
#   павлоградец: 11
#   бегать: 11
#   наблюдать: 11
#   бархатный: 11
#   милка: 11
#   кроватка: 11
#   париж: 11
#   чемодан: 11
#   убеждение: 11
#   отступить: 11
#   хохот: 11
#   объяснять: 11
#   опушка: 11
#   усталость: 11
#   браунау: 11
#   бурьен: 11
#   море: 11
#   мороз: 11
#   маша: 11
#   оживлённо: 11
#   братец: 11
#   любоваться: 11
#   васька: 11
#   отличный: 11
#   меланхолия: 11
#   локоть: 11
#   благо: 11
#   мелюковый: 11
#   цвет: 11
#   урра: 11
#   опоздать: 11
#   миллион: 11
#   переводить: 11
#   насмешливый: 11
#   некрасивый: 11
#   таинственный: 11
#   карман: 11
#   подтвердить: 11
#   нездоровый: 11
#   каков: 11
#   сущность: 11
#   одобрять: 11
#   кавалергард: 11
#   акт: 11
#   поздравлять: 11
#   показываться: 11
#   незаконный: 11
#   богданович: 11
#   покачивать: 11
#   испугаться: 11
#   богатство: 11
#   исключение: 11
#   кирилл: 11
#   насмешливо: 11
#   класть: 11
#   торжественно: 11
#   переговорить: 11
#   мило: 11
#   милостивый: 11
#   коротко: 11
#   комиссия: 11
#   оживиться: 11
#   больница: 11
#   топот: 11
#   вмешаться: 11
#   внешний: 11
#   кожа: 11
#   француженка: 11
#   кобель: 11
#   повод: 11
#   нарядить: 11
#   той: 11
#   тильзита: 11
#   трудный: 11
#   милорадович: 11
#   молиться: 12
#   овраг: 12
#   работать: 12
#   покорно: 12
#   разделять: 12
#   начинаться: 12
#   ребята: 12
#   десятый: 12
#   необыкновенно: 12
#   неожиданный: 12
#   напрасно: 12
#   неподвижный: 12
#   неправда: 12
#   непреодолимый: 12
#   несчастливый: 12
#   рассматривать: 12
#   низкий: 12
#   доказать: 12
#   мрачно: 12
#   обойти: 12
#   долгий: 12
#   рама: 12
#   морщиться: 12
#   разнообразный: 12
#   морщина: 12
#   допустить: 12
#   обязать: 12
#   обернуться: 12
#   житель: 12
#   оживление: 12
#   пара: 12
#   застать: 12
#   захватить: 12
#   зашевелиться: 12
#   преданность: 12
#   крепкий: 12
#   почтительный: 12
#   переговариваться: 12
#   походка: 12
#   количество: 12
#   посреди: 12
#   поглядеть: 12
#   кланяться: 12
#   посидеть: 12
#   катишь: 12
#   канава: 12
#   пожилой: 12
#   кавалер: 12
#   изменять: 12
#   измученный: 12
#   покидать: 12
#   круглый: 12
#   оглянуть: 12
#   кружок: 12
#   кузина: 12
#   противный: 12
#   метивье: 12
#   озлобление: 12
#   пробыть: 12
#   приятель: 12
#   притворный: 12
#   маршал: 12
#   императрица: 12
#   прислушаться: 12
#   остров: 12
#   отбить: 12
#   лучистый: 12
#   ложь: 12
#   заглянуть: 12
#   лишний: 12
#   приложить: 12
#   отрадный: 12
#   заключить: 12
#   отступление: 12
#   отсутствие: 12
#   приблизиться: 12
#   крыша: 12
#   погибнуть: 12
#   невидимый: 12
#   сожаление: 12
#   благодаря: 12
#   умолять: 12
#   штык: 12
#   супруг: 12
#   благодарный: 12
#   господь: 12
#   гувернантка: 12
#   упорно: 12
#   ступень: 12
#   семён: 12
#   составить: 12
#   учить: 12
#   смутить: 12
#   аудитор: 12
#   выпустить: 12
#   гордый: 12
#   аустерлица: 12
#   шевелиться: 12
#   сложить: 12
#   хлеб: 12
#   всеять: 12
#   стая: 12
#   срок: 12
#   услуга: 12
#   чиновник: 12
#   спрятать: 12
#   скучно: 12
#   вчерашний: 12
#   буонапарта: 12
#   больно: 12
#   счесть: 12
#   спор: 12
#   глубина: 12
#   родиться: 12
#   убежать: 12
#   владимирович: 12
#   уверенный: 12
#   толпиться: 12
#   толк: 12
#   российский: 12
#   внушать: 12
#   рюмка: 12
#   роль: 12
#   сойтись: 12
#   божественный: 12
#   бок: 12
#   яркий: 12
#   верхний: 12
#   согласный: 12
#   дальний: 12
#   требование: 12
#   съездить: 12
#   связать: 12
#   ридикюль: 12
#   удаться: 12
#   шёлковый: 12
#   почётный: 13
#   поэтому: 13
#   боль: 13
#   поцелуй: 13
#   спаситель: 13
#   усталый: 13
#   выгодный: 13
#   буксгевдный: 13
#   приказывать: 13
#   вызывать: 13
#   хватать: 13
#   представиться: 13
#   православный: 13
#   пригласить: 13
#   фамилия: 13
#   учтивость: 13
#   приглашать: 13
#   заложить: 13
#   борьба: 13
#   преимущественно: 13
#   уходить: 13
#   презрительный: 13
#   мелкий: 13
#   сочувствие: 13
#   прийтись: 13
#   фёдорович: 13
#   выпускать: 13
#   звучать: 13
#   предлог: 13
#   гвардейский: 13
#   мерзавец: 13
#   заняться: 13
#   услышать: 13
#   воротник: 13
#   вели: 13
#   воображать: 13
#   венский: 13
#   умирающий: 13
#   оттенок: 13
#   узкий: 13
#   отъехать: 13
#   карьера: 13
#   воспитание: 13
#   удержаться: 13
#   ударять: 13
#   повернуть: 13
#   убрать: 13
#   вне: 13
#   торжество: 13
#   крепко: 13
#   пение: 13
#   перевести: 13
#   кочубей: 13
#   возможно: 13
#   выговаривать: 13
#   познакомиться: 13
#   ловко: 13
#   отвращение: 13
#   майор: 13
#   лёд: 13
#   измена: 13
#   важность: 13
#   поморщиться: 13
#   вскоре: 13
#   столик: 13
#   столкновение: 13
#   строиться: 13
#   полно: 13
#   упрекать: 13
#   стон: 13
#   вейротереть: 13
#   страстно: 13
#   искусство: 13
#   употреблять: 13
#   покой: 13
#   поклон: 13
#   восторженно: 13
#   вбежать: 13
#   откуда: 13
#   визит: 13
#   многий: 13
#   достижение: 13
#   равнодушный: 13
#   ниже: 13
#   грех: 13
#   пример: 13
#   балаган: 13
#   пятнадцать: 13
#   дура: 13
#   прямой: 13
#   прощение: 13
#   госпиталь: 13
#   протянуть: 13
#   противоположный: 13
#   горячность: 13
#   белые: 13
#   ноябрь: 13
#   жалкий: 13
#   аустерлицкий: 13
#   горло: 13
#   несправедливый: 13
#   шесть: 13
#   недалеко: 13
#   ярко: 13
#   детство: 13
#   ангел: 13
#   рассыпать: 13
#   расстояние: 13
#   свадьба: 13
#   рассмотреть: 13
#   натали: 13
#   насчёт: 13
#   рано: 13
#   семейный: 13
#   семья: 13
#   направиться: 13
#   разойтись: 13
#   артиллерия: 13
#   различный: 13
#   атмосфера: 13
#   обдумать: 13
#   чуждый: 13
#   жестокий: 13
#   жеркова: 13
#   собеседник: 13
#   событие: 13
#   говориться: 13
#   обходить: 13
#   обращение: 13
#   бешенство: 13
#   мрак: 13
#   собрать: 13
#   молчаливый: 13
#   женатый: 13
#   совершиться: 13
#   общественный: 13
#   беспокоиться: 13
#   многое: 13
#   стоя: 14
#   внизу: 14
#   оторвать: 14
#   плотина: 14
#   истинный: 14
#   грубый: 14
#   пари: 14
#   покачать: 14
#   высунуться: 14
#   иосиф: 14
#   приветствие: 14
#   поклониться: 14
#   губка: 14
#   дорожить: 14
#   сергей: 14
#   страстный: 14
#   благородный: 14
#   ложиться: 14
#   лично: 14
#   отлично: 14
#   неохотно: 14
#   темно: 14
#   рысью: 14
#   придавать: 14
#   кивнуть: 14
#   добродетельный: 14
#   весна: 14
#   веселие: 14
#   уезжать: 14
#   неизвестный: 14
#   лазарев: 14
#   флигель: 14
#   признавать: 14
#   рассеянный: 14
#   ланжерон: 14
#   шум: 14
#   ненавидеть: 14
#   наука: 14
#   уверенность: 14
#   апраксин: 14
#   ранний: 14
#   уничтожить: 14
#   милость: 14
#   подсесть: 14
#   либо: 14
#   уверить: 14
#   заседание: 14
#   успокоиться: 14
#   вечный: 14
#   сотня: 14
#   чин: 14
#   значить: 14
#   устав: 14
#   прочь: 14
#   неестественно: 14
#   тридцать: 14
#   выдержать: 14
#   устать: 14
#   европа: 14
#   пространство: 14
#   выказать: 14
#   робеть: 14
#   злобно: 14
#   поэтический: 14
#   проснуться: 14
#   утешение: 14
#   затворить: 14
#   молитва: 14
#   выскочить: 14
#   вынуть: 14
#   неестественный: 14
#   отвести: 14
#   занять: 14
#   чулок: 14
#   полчаса: 14
#   перемениться: 14
#   польский: 14
#   партер: 14
#   сильно: 14
#   вздох: 14
#   старушка: 14
#   пятьдесят: 14
#   сопутствовать: 14
#   приближение: 14
#   проигрыш: 14
#   одеяло: 14
#   мучительный: 14
#   вспыхнуть: 14
#   чистота: 14
#   любящий: 14
#   печальный: 14
#   нежность: 14
#   ножка: 14
#   посадить: 14
#   махать: 14
#   эрцгерцог: 15
#   папа: 15
#   пахнуть: 15
#   английский: 15
#   благодетель: 15
#   перебивать: 15
#   участь: 15
#   накануне: 15
#   наступить: 15
#   участвовать: 15
#   часы: 15
#   опасность: 15
#   няня: 15
#   беспокойство: 15
#   окончить: 15
#   наверное: 15
#   нота: 15
#   новость: 15
#   нисколько: 15
#   быстрота: 15
#   кузьмич: 15
#   открыться: 15
#   назвать: 15
#   назначение: 15
#   оживляться: 15
#   фельдмаршал: 15
#   намеренный: 15
#   обстоятельство: 15
#   велено: 15
#   анне: 15
#   анисья: 15
#   лента: 15
#   настроение: 15
#   местность: 15
#   денщик: 15
#   тайный: 15
#   союз: 15
#   выразиться: 15
#   презрение: 15
#   выражаться: 15
#   старческий: 15
#   грязный: 15
#   довести: 15
#   предмет: 15
#   карать: 15
#   карагина: 15
#   счастливо: 15
#   раскраснеться: 15
#   деятельность: 15
#   поездка: 15
#   проститься: 15
#   разлука: 15
#   раскрытый: 15
#   прошедшее: 15
#   радоваться: 15
#   серебряный: 15
#   восемь: 15
#   готовиться: 15
#   распоряжение: 15
#   выбирать: 15
#   дворовый: 15
#   поручик: 15
#   вступать: 15
#   путешествие: 15
#   интересный: 15
#   снова: 15
#   среди: 15
#   существование: 15
#   сосед: 15
#   презирать: 15
#   соединение: 15
#   перемирие: 15
#   гнев: 15
#   жёлтый: 15
#   переставать: 15
#   гончий: 15
#   река: 15
#   пистолет: 15
#   подвинуться: 15
#   пленный: 15
#   заиграть: 15
#   седло: 15
#   диммлера: 15
#   скрыть: 15
#   выступить: 15
#   вовсе: 15
#   смутиться: 15
#   тетрадь: 15
#   смысл: 16
#   спускаться: 16
#   храбрый: 16
#   благородие: 16
#   встречать: 16
#   обнимать: 16
#   незнакомый: 16
#   отдавать: 16
#   сосредоточить: 16
#   выступать: 16
#   отдохнуть: 16
#   дуб: 16
#   царь: 16
#   пробежать: 16
#   солдатский: 16
#   приговаривать: 16
#   гадкий: 16
#   мгновенно: 16
#   правило: 16
#   появиться: 16
#   бросать: 16
#   фрак: 16
#   мокрый: 16
#   ха: 16
#   провожать: 16
#   данил: 16
#   честной: 16
#   ближний: 16
#   наблюдение: 16
#   хозяйка: 16
#   знаменитый: 16
#   запах: 16
#   столовая: 16
#   получать: 16
#   грязь: 16
#   возможный: 16
#   также: 16
#   старичок: 16
#   непонятный: 16
#   родитель: 16
#   увлечение: 16
#   павлоградский: 16
#   робкий: 16
#   недоумение: 16
#   рана: 16
#   ковёр: 16
#   куст: 16
#   тоненький: 16
#   крест: 16
#   торопиться: 16
#   недавно: 16
#   перонский: 16
#   невысокий: 16
#   перебирать: 16
#   святой: 16
#   тяжесть: 16
#   шуба: 16
#   трубка: 16
#   перемена: 16
#   котора: 16
#   необыкновенный: 16
#   таинство: 16
#   разобрать: 16
#   позвать: 16
#   пятно: 16
#   упрёк: 16
#   иогель: 16
#   покойный: 16
#   исполнение: 16
#   век: 16
#   отпуск: 16
#   позиция: 16
#   лист: 16
#   официант: 16
#   поза: 16
#   сцена: 16
#   растопчина: 16
#   собственный: 16
#   сени: 16
#   наклонить: 16
#   доска: 16
#   дорогой: 16
#   досада: 16
#   свойственный: 17
#   складка: 17
#   храбрость: 17
#   сидя: 17
#   пётр: 17
#   англичанин: 17
#   обоз: 17
#   нижний: 17
#   пускать: 17
#   неловкий: 17
#   пропустить: 17
#   проиграть: 17
#   доказывать: 17
#   мрачный: 17
#   слабость: 17
#   разумеется: 17
#   цыпочки: 17
#   шпор: 17
#   берег: 17
#   сердитый: 17
#   мужик: 17
#   слыхать: 17
#   пьяный: 17
#   совершаться: 17
#   полок: 17
#   ура: 17
#   лощина: 17
#   интересовать: 17
#   стрельба: 17
#   исчезнуть: 17
#   отпустить: 17
#   сходить: 17
#   умирать: 17
#   отходить: 17
#   отчаяние: 17
#   отчаянный: 17
#   живо: 17
#   подруга: 17
#   касаться: 17
#   удержать: 17
#   клавикорд: 17
#   темнота: 17
#   ветер: 17
#   внимательно: 17
#   толстой: 17
#   резкий: 17
#   крестьянин: 17
#   влияние: 17
#   переход: 17
#   трястись: 17
#   лаврушка: 17
#   старательно: 17
#   урок: 17
#   посланник: 17
#   забывать: 17
#   обычный: 17
#   совестно: 17
#   блеск: 17
#   присесть: 17
#   свитский: 17
#   дипломатический: 17
#   заехать: 17
#   приказ: 17
#   одинаково: 17
#   замечание: 17
#   привычный: 17
#   поручение: 17
#   выход: 17
#   фельдшер: 17
#   вилларский: 17
#   маменька: 17
#   манера: 17
#   значительный: 17
#   выгода: 17
#   спасти: 17
#   опуститься: 17
#   привести: 17
#   мастер: 17
#   праздник: 17
#   дворец: 17
#   окружать: 17
#   медленно: 17
#   далее: 17
#   экипаж: 18
#   рост: 18
#   нежно: 18
#   тронуться: 18
#   сердиться: 18
#   переходить: 18
#   печаль: 18
#   тётушка: 18
#   повести: 18
#   папенька: 18
#   падать: 18
#   угрожать: 18
#   ударить: 18
#   решение: 18
#   оттуда: 18
#   подхватить: 18
#   суворов: 18
#   портрет: 18
#   оставлять: 18
#   ольмюца: 18
#   придворный: 18
#   принадлежать: 18
#   приподнять: 18
#   обман: 18
#   обворожительный: 18
#   пропасть: 18
#   следить: 18
#   серый: 18
#   шляпа: 18
#   ожидание: 18
#   аббат: 18
#   вскрикнуть: 18
#   наивный: 18
#   кучер: 18

# %%
import numpy as np

# bow_sum: array of token counts across the corpus
num_tokens_gt_10 = np.sum(bow_sum > 24)

print("Number of tokens with frequency > 10:", num_tokens_gt_10)
# Out:
# Number of tokens with frequency > 10: 976

# %%
import numpy as np

# bow_sum: array of token counts across all documents
# vectorizer: your CountVectorizer

# 1. Create a boolean mask for tokens with frequency > 24
mask = bow_sum > 24

# 2. Get indices of tokens that satisfy the mask
valid_indices = np.where(mask)[0]

# 3. Sort these indices by frequency descending
sorted_indices = valid_indices[np.argsort(bow_sum[valid_indices])[::-1]]

# 4. Retrieve the token strings
tokens_sorted = [vectorizer.get_feature_names_out()[i] for i in sorted_indices]

# 5. Optional: also get their frequencies
frequencies_sorted = bow_sum[sorted_indices]

# 6. Print token and frequency
for token, freq in zip(tokens_sorted, frequencies_sorted):
    print(token, freq)
# Out:
# скромность 1976
# поискать 1973
# избежание 1766
# подогнуть 1661
# зато 1531
# вовремя 1457
# вражда 1148
# отрицательный 957
# бунтовать 890
# кричать 864
# аленин 855
# жгучий 801
# лис 757
# рыскать 742
# камень 669
# плутоватый 649
# горестный 638
# побудить 610
# воткнуть 545
# выкатываться 455
# затихание 448
# встряхнуть 448
# гидра 439
# владимир 432
# вася 417
# настроить 393
# робеть 360
# предупредить 353
# коленка 352
# география 347
# вредить 342
# боков 331
# междуцарствие 330
# полудевочка 324
# подробность 321
# постоять 314
# понемногу 312
# здоговый 300
# вспышка 299
# настаивание 285
# лишить 284
# заморённый 282
# врач 280
# налево 279
# голосок 278
# выламывать 277
# назначить 275
# робеспьер 273
# корявый 269
# беспокоить 268
# вступительный 267
# крайность 263
# выкупаться 262
# небритый 262
# аллея 262
# праздный 262
# жизнь 262
# кверху 257
# выстрел 256
# пресечься 255
# грация 252
# картинка 247
# беседовать 246
# возня 244
# выступление 240
# выказывать 240
# посреди 235
# безумный 234
# сбыться 232
# развести 230
# позволение 230
# приминать 228
# василий 223
# представлять 223
# акушерка 217
# выдавать 213
# загорелый 211
# николушка 209
# воспоминать 206
# масть 206
# подбить 206
# корпусный 205
# отягчать 205
# ключевой 204
# оправляться 203
# иронический 200
# обладатель 199
# выговор 199
# неловкий 195
# корабль 193
# развеселиться 190
# прервать 190
# меморандум 188
# вражек 180
# божество 179
# горестно 178
# гостеприимный 176
# мелюковый 175
# сбываться 174
# неудовлетворение 171
# вздох 171
# несомненно 171
# вписывать 166
# волновать 165
# василь 164
# меланхоличный 164
# надсаживать 163
# медвежий 163
# загореться 163
# отечь 161
# поверхность 160
# пружина 160
# преображенец 160
# беспутный 160
# затеять 160
# отбыть 158
# антонов 157
# облегчение 157
# крестьянский 157
# выстроить 157
# светить 155
# готовность 155
# гость 154
# бытность 151
# образовать 150
# ма 149
# ангела 149
# расшевелиться 149
# замок 148
# мишка 148
# кость 148
# приличный 146
# коля 145
# озадачить 144
# глина 144
# берёзовый 143
# обрезать 142
# крытый 141
# вздор 140
# бережно 139
# беспредельный 138
# бурдастый 138
# польстить 136
# аплодисменты 136
# вытянутый 136
# месяц 135
# поздороветь 134
# поляк 134
# вспотеть 132
# наташка 131
# расширяться 130
# подлететь 130
# вейротереть 128
# кивать 127
# адам 127
# грешить 126
# вист 126
# неизбежный 125
# едкий 124
# вахмистр 124
# нечаянно 124
# математика 123
# звать 122
# осаживать 121
# пётр 121
# добежать 120
# мрачный 119
# предписывать 118
# куча 118
# няня 117
# буонапартия 117
# надворный 117
# отголосок 116
# отбивать 116
# плыть 115
# воображать 115
# гарденберг 114
# опускаться 114
# прилипнуть 114
# развестись 114
# празднование 113
# предпоследний 113
# молитен 113
# руно 112
# склонность 112
# некто 109
# выпустить 109
# превыше 109
# мечтаться 108
# метла 108
# изречение 107
# обгонять 106
# всадник 105
# перехватывать 104
# мнение 103
# взятие 102
# поручиться 101
# оградить 101
# ненавистный 101
# изнутри 100
# внешность 100
# выдаться 100
# кригс 99
# вырезать 99
# бюджет 98
# обжиться 97
# простор 97
# деться 97
# положить 97
# лихорадка 97
# латынь 95
# алексеевич 95
# бесконечность 95
# близость 95
# вылечиться 94
# огонёк 94
# господствовать 94
# настроение 94
# пора 93
# вслушиваться 93
# вовлечь 93
# выборы 93
# го 93
# багратионов 93
# неминуемый 93
# помолиться 93
# личина 93
# робко 93
# округление 92
# выспрашивать 92
# вбегать 92
# извозчик 91
# выверт 91
# вылететь 90
# марго 89
# брюзгливость 88
# нэ 88
# откос 88
# ручей 88
# ахнуть 88
# надеяться 88
# отозваться 87
# заменять 87
# беззвучный 87
# никуда 87
# круглый 87
# лаврушка 87
# вздвижёнка 86
# братство 85
# истощить 85
# пройтись 85
# вылежать 85
# восхитить 85
# коситься 85
# личный 84
# бал 84
# изгонять 84
# вериться 84
# надушить 84
# почтение 84
# сбегать 83
# озёры 82
# височек 81
# приблизить 81
# метать 81
# нынче 81
# обратно 80
# мольеровый 80
# истина 80
# безнадёжно 80
# озариться 80
# продолжительно 80
# выступ 80
# измять 79
# речь 79
# подёргивать 79
# выбыть 79
# обмундироваться 78
# молчать 78
# перейти 78
# изнеможение 78
# разрушать 77
# буксгевдный 77
# равномерно 77
# море 76
# образованный 76
# молить 75
# василья 75
# апостол 75
# пожатие 75
# брульон 73
# главный 73
# нескромность 73
# вздёргиваться 73
# пробурлить 73
# вызваться 73
# пережёвывать 72
# нерешённый 72
# губернский 72
# отталкивать 72
# жарка 72
# мужской 71
# зелье 71
# полубугор 71
# обязаться 71
# провинциал 71
# блуза 70
# сердечность 70
# мерно 70
# пристрастие 70
# брюнна 70
# поутру 70
# выводка 70
# кротость 69
# слепнуть 69
# пик 69
# помещение 69
# ворчать 69
# наслаждение 68
# гладко 68
# наведываться 68
# вставлять 68
# выводить 68
# вспоминаться 68
# пыль 68
# расплакаться 68
# оглянуться 67
# ноябрь 67
# русь 67
# разврат 67
# пятидесятилетний 67
# приманка 67
# мужчина 66
# корсет 66
# августейший 66
# сажный 66
# полушёпот 66
# ротик 66
# пожаться 65
# вводить 65
# пренебрежение 65
# берёза 64
# вспомниться 64
# атмосфера 64
# поздравление 64
# прибрать 64
# неуспех 64
# наполеоновский 63
# наддать 63
# краснеться 63
# печерский 63
# робкий 63
# разговаривать 62
# красный 62
# закричать 62
# госпожа 62
# подробный 62
# масса 62
# прохаживаться 62
# йорк 61
# свесить 61
# надеть 61
# высота 60
# протекция 60
# жучок 60
# живописно 60
# поэтому 60
# повторение 60
# выплакать 60
# великолепный 60
# проезжать 60
# оправить 60
# гроб 59
# равенство 59
# жёлчный 59
# лихтенфельс 59
# поездить 58
# даль 58
# государственный 58
# исполнить 58
# ласковый 58
# непосредственно 57
# припасти 57
# присутствие 57
# никто 57
# лабиринт 57
# вчетверо 57
# загнать 57
# неприятельский 57
# артиллерист 56
# куст 56
# оставлять 56
# покровитель 56
# подмазка 56
# невредимый 56
# настоятельность 56
# михаил 56
# поиграть 56
# оспаривать 56
# получиться 56
# необыкновенный 55
# локоть 55
# прослезиться 55
# осторожный 55
# нынешний 55
# вправо 55
# невыносимый 55
# довспоминаться 55
# вздрагивать 55
# богатый 55
# двенадцать 55
# ожидание 55
# посадить 54
# рота 54
# заехать 54
# прищуриться 54
# нянька 54
# вурстый 54
# кружиться 54
# оружие 54
# котлы 54
# брюмер 54
# лихой 53
# выносить 53
# помилование 53
# монастырь 53
# голубой 53
# пруссия 53
# нырнуть 53
# выкапывать 53
# нянчить 53
# наука 53
# бульон 53
# лихтенштейн 52
# книжный 52
# затем 52
# атеист 52
# измаильский 52
# медный 52
# разгадка 52
# взорвать 52
# предрассудок 52
# месячный 52
# водомоина 51
# отступить 51
# инструмент 51
# азарт 51
# сашинет 51
# восхищаться 51
# ограниченный 51
# законодательный 51
# овраг 51
# обручить 51
# вода 51
# прибавление 51
# неизменный 51
# отсырелый 51
# разочаровать 50
# отсрочка 50
# миг 50
# покоряться 50
# плюмаж 50
# пользоваться 50
# набело 50
# николушко 50
# окаймлять 50
# вздохнуть 49
# отлично 49
# досуг 49
# приёмный 49
# иларионович 49
# принимать 49
# низвергнуть 49
# лоб 49
# получать 49
# присесть 48
# полянка 48
# надрываться 48
# опутать 48
# блок 48
# назначение 48
# вверить 48
# скрип 48
# вместо 47
# отсесть 47
# государство 47
# немедля 47
# приветствовать 47
# неман 47
# зашуметь 47
# неверно 47
# муха 47
# безупречный 47
# прорвать 47
# поляна 47
# нескучно 46
# сидение 46
# княжна 46
# выпускать 46
# заключение 46
# подъехать 46
# представить 46
# накидывать 46
# выпадать 46
# братия 46
# ляскнуть 45
# любопытство 45
# москва 45
# восхитительный 45
# поэтичность 45
# негде 45
# пугаться 45
# коленкура 45
# диктовать 45
# плюнуть 45
# веер 45
# езженный 45
# опухлость 45
# благоразумный 45
# немилость 45
# вкус 45
# пережить 45
# выставить 44
# колебать 44
# блюдо 44
# буря 44
# клятва 44
# зачесать 44
# вопросительно 44
# позабавиться 44
# препона 44
# неизменно 44
# односложно 44
# истомленный 44
# бригадир 44
# лезть 44
# прибор 43
# мраморный 43
# неуклюже 43
# каприз 43
# зажигать 43
# встряхнуться 43
# неодобрение 43
# оживляться 43
# встряхивать 43
# поучаться 43
# естественность 43
# загнуть 43
# сапожок 43
# запрячь 43
# закурить 42
# растолковывать 42
# впечатление 42
# самозабвение 42
# развёртывать 42
# выдать 42
# вечером 42
# расступиться 42
# арифметический 42
# подножка 42
# покров 42
# пегедать 42
# причёска 42
# ползти 42
# попивать 42
# пикет 42
# оправиться 42
# кусать 42
# отягощать 42
# плохой 42
# сбежать 41
# изворотливость 41
# предмет 41
# отстаивать 41
# армейщина 41
# выиграть 41
# заговорщик 41
# беззаботно 41
# лысый 41
# ненужный 41
# важность 41
# сдаточный 40
# бурный 40
# обвенчаться 40
# вывести 40
# отпрячь 40
# буонапарта 40
# откашляться 40
# вникнуть 40
# отвёртываться 40
# засучить 40
# назначаться 40
# распределять 40
# нимало 40
# нечестный 40
# канонада 40
# непостоянство 40
# висячий 40
# бешеный 40
# ливрея 40
# вместе 40
# ось 39
# вздуть 39
# изредка 39
# ползком 39
# насилу 39
# еда 39
# настави 39
# обряд 39
# впиваться 39
# придвинуть 39
# отступление 39
# логичность 39
# нож 39
# почитатель 39
# злодей 38
# мешать 38
# диадема 38
# башмак 38
# коренник 38
# вилльнев 38
# обыкновенно 38
# обиженно 38
# бубенец 38
# значительно 38
# рытвина 38
# волна 38
# протестовать 37
# ваша 37
# подлость 37
# помигать 37
# раздражительный 37
# матрешить 37
# глупость 37
# жест 37
# безнадёжность 37
# бешенство 37
# готовить 37
# назидательный 37
# квартирка 37
# придерживаться 37
# мачта 37
# непреодолимый 37
# неизменяемый 37
# отнимать 37
# андрей 36
# договорить 36
# нелюбезный 36
# артикул 36
# показание 36
# подстава 36
# наследство 36
# провинция 36
# пожалуйста 36
# венский 36
# миновать 36
# корчить 36
# надгробный 36
# ввести 36
# высылать 36
# неурожай 36
# отвернуться 36
# кх 36
# набожный 36
# поглотить 36
# рознить 36
# недоумение 35
# нерешительно 35
# жар 35
# маркитант 35
# жабо 35
# лохматый 35
# запрег 35
# отогнать 35
# комиссионер 35
# выгодно 35
# лично 35
# самосовершенствование 35
# напаиван 35
# курагин 35
# воспользоваться 35
# одушевить 35
# взятка 35
# пиеска 35
# сделать 34
# добренек 34
# потянуть 34
# сладкое 34
# бритый 34
# рифея 34
# грабёж 34
# обязанность 34
# пожаловаться 34
# вызвать 34
# попытаться 34
# оказываться 34
# почётный 34
# обновление 34
# выразительный 34
# кривая 34
# квадрат 34
# пронзать 34
# задребезжать 34
# змея 34
# мгновение 34
# замолкать 34
# привидение 34
# задать 34
# кусочек 34
# отвращение 33
# орудийный 33
# бе 33
# вифлянка 33
# беготня 33
# жаловаться 33
# записать 33
# вскидывать 33
# разрушить 33
# законный 33
# рубило 33
# лампадка 33
# побледнеть 33
# румянец 33
# блестящий 33
# качать 33
# отсюда 33
# ретироваться 33
# сизый 33
# насторожить 32
# рии 32
# пятисоттысячный 32
# опасаться 32
# поссорить 32
# ростовский 32
# разноцветный 32
# отвес 32
# подбородок 32
# заём 32
# перил 32
# постичь 32
# вьющийся 32
# завалиться 32
# обижать 32
# жалкий 32
# сеть 32
# прибавить 32
# внести 32
# бессильный 32
# пронзительный 32
# приведение 32
# волнующий 31
# город 31
# молодая 31
# макарина 31
# вложить 31
# испужаться 31
# свежесть 31
# обидеться 31
# муравей 31
# пучина 31
# засидеться 31
# восемьдесят 31
# лёжа 31
# провезти 31
# проиграться 31
# неотступно 31
# добыча 31
# голицын 31
# неизведанный 31
# десятилетний 31
# казарма 31
# долгоруков 30
# непонятно 30
# граф 30
# вспрыгнуть 30
# кол 30
# пещера 30
# посторониться 30
# повёртываться 30
# покровительство 30
# матрёшка 30
# несильный 30
# откинуться 30
# главноуправлять 30
# вбежать 30
# возможный 30
# препровождение 30
# наступление 30
# внутри 30
# андрюша 30
# завод 30
# возбудить 30
# лицезрение 30
# кабак 30
# отворачиваться 30
# обдёргивать 30
# проповедовать 30
# ночью 30
# оживлённый 30
# желаемый 30
# краснота 30
# величавость 29
# подстрелить 29
# величественно 29
# изрубить 29
# ловить 29
# полутёмный 29
# военный 29
# вдыхать 29
# сдунуть 29
# повторять 29
# легко 29
# полный 29
# пристроиться 29
# бесценный 29
# озябнуть 29
# бугор 29
# брюнном 29
# высунуть 29
# забивать 29
# глупо 29
# жеркова 29
# распространиться 29
# нечувствительный 29
# привязаться 29
# неизбежно 29
# нестройный 29
# двоюродный 29
# доходить 29
# дико 29
# остралицо 29
# высочество 29
# равнодушно 29
# навес 29
# входящий 29
# выбрать 29
# расшириться 28
# аренда 28
# горничный 28
# разонять 28
# жаровой 28
# пёстрый 28
# медлить 28
# втягивать 28
# метампсикоз 28
# неприступный 28
# присылка 28
# отрадный 28
# положа 28
# предать 28
# договаривать 28
# впервые 28
# лекарский 28
# осуществиться 28
# оборачивать 28
# подстелить 28
# обстричь 28
# кадка 28
# благоговеть 28
# пятница 28
# мародёр 28
# осмелиться 28
# попечение 28
# молчание 28
# задача 28
# ольденбургский 28
# кончиться 27
# портить 27
# полицеймейстер 27
# краля 27
# век 27
# потесниться 27
# доверенный 27
# сечь 27
# противный 27
# рама 27
# живописец 27
# рвануться 27
# обтираться 27
# приколоть 27
# описательный 27
# приласкать 27
# закраснеться 27
# быт 27
# выжидать 27
# молодцеватый 27
# известие 27
# педаль 27
# пристукнуть 27
# изготовиться 27
# прищёлкнуть 27
# подвергнуть 27
# люстра 27
# внимание 27
# ложь 27
# лазарев 27
# бой 27
# беззвучно 26
# мельком 26
# мейнный 26
# преступный 26
# кавалерист 26
# остзейский 26
# положительно 26
# край 26
# круглолицый 26
# кругом 26
# лепёшка 26
# переменяться 26
# парик 26
# отсутствие 26
# мелочь 26
# меньшой 26
# мишень 26
# навытяжка 26
# отказывать 26
# наряд 26
# неслыханный 26
# несносно 26
# обморок 26
# изобразить 26
# обхватить 26
# приказывать 26
# разлиться 26
# воображение 26
# втыкать 26
# резвость 26
# высадка 26
# высказываться 26
# геометрия 26
# званый 26
# глава 26
# девять 26
# захрипеть 26
# продел 26
# пятнадцать 25
# покашливание 25
# рррра 25
# поскакать 25
# расплываться 25
# раненый 25
# пролететь 25
# пища 25
# размещение 25
# бартенштейн 25
# отклонить 25
# пятнадцатилетний 25
# подтвердить 25
# прац 25
# великодушный 25
# однако 25
# напоминание 25
# возмутить 25
# входной 25
# выдвинуться 25
# вылечивать 25
# выстрелить 25
# гошпитала 25
# гусли 25
# доктор 25
# дохтуров 25
# едать 25
# зравие 25
# извлекать 25
# княгинина 25
# колет 25
# кончик 25
# корник 25
# куверт 25
# лифляндский 25
# беспрестанно 25
# мария 25
# матка 25
# возвратить 25
# меланхолический 25
# слетать 25

# %%
import wn

# Example token
token = "кот"

# Get Russian synsets (OMW)
synsets_ru = wn.synsets(token, lang='ru')

# Extract German lemmas for each synset
german_equivs = set()
for syn in synsets_ru:
    for lemma in syn.lemmas(lang='de'):
        german_equivs.add(lemma)

print(token, "→", german_equivs)
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# Cell In[26], line 7
#       4 token = "кот"
#       6 # Get Russian synsets (OMW)
# ----> 7 synsets_ru = wn.synsets(token, lang='ru')
#       9 # Extract German lemmas for each synset
#      10 german_equivs = set()
#
# File ~/Documents/Code/NLP_Uni/.venv10/lib/python3.10/site-packages/wn/_module_functions.py:136, in synsets(form, pos, ili, lexicon, lang)
#     116 def synsets(
#     117     form: Optional[str] = None,
#     118     pos: Optional[str] = None,
#    (...)
#     122     lang: Optional[str] = None,
#     123 ) -> list[wn.Synset]:
#     124     """Return the list of matching synsets.
#     125
#     126     This will create a :class:`Wordnet` object using the *lang* and
#    (...)
#     134
#     135     """
# --> 136     return wn.Wordnet(lang=lang, lexicon=lexicon).synsets(form=form, pos=pos, ili=ili)
#
# File ~/Documents/Code/NLP_Uni/.venv10/lib/python3.10/site-packages/wn/_core.py:1423, in Wordnet.__init__(self, lexicon, lang, expand, normalizer, lemmatizer, search_all_forms)
#    1412 def __init__(
#    1413     self,
#    1414     lexicon: Optional[str] = None,
#    (...)
#    1420     search_all_forms: bool = True,
#    1421 ):
#    1422     if lexicon or lang:
# -> 1423         lexicons = tuple(resolve_lexicon_specifiers(lexicon or '*', lang=lang))
#    1424     else:
#    1425         lexicons = ()
#
# File ~/Documents/Code/NLP_Uni/.venv10/lib/python3.10/site-packages/wn/_queries.py:132, in resolve_lexicon_specifiers(lexicon, lang)
#     130 # only raise an error when the query specifies something
#     131 if not specifiers and (lexicon != '*' or lang is not None):
# --> 132     raise wn.Error(
#     133         f'no lexicon found with lang={lang!r} and lexicon={lexicon!r}'
#     134     )
#     135 return specifiers
#
# Error: no lexicon found with lang='ru' and lexicon='*'
